# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint as pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={api_key}&units={units}&q="


response = requests.get(query_url + "rikitea").json()
        
response
# Out:
# {'coord': {'lon': -134.97, 'lat': -23.12},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 22.95,
#   'pressure': 1018.65,
#   'humidity': 62,
#   'temp_min': 22.95,
#   'temp_max': 22.95,
#   'sea_level': 1018.65,
#   'grnd_level': 1018.44},
#  'wind': {'speed': 2.7, 'deg': 112.656},
#  'clouds': {'all': 72},
#  'dt': 1558464069,
#  'sys': {'message': 0.0058,
#   'country': 'PF',
#   'sunrise': 1558452533,
#   'sunset': 1558491861},
#  'id': 4030556,
#  'name': 'Rikitea',
#  'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed

# %%
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
name = []


url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={api_key}&units={units}&q="

for x in range(len(cities)):
    try:
        print(f"Processing Record {x} of {len(cities)}  | {cities[x]}")
        #for city in cities:
            
        response = requests.get(query_url + cities[x]).json()
            
            #for weather in response:
            
            #print(response)
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        country.append(response["sys"]["country"])
        wind_speed.append(response["wind"]["speed"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        date.append(response["sys"]["sunrise"])
        name.append(response["name"])

        
 
    except KeyError:
        print(f"City not found. Skipping...")
# Out:
# Processing Record 0 of 633  | east london
# Processing Record 1 of 633  | avarua
# Processing Record 2 of 633  | lebu
# Processing Record 3 of 633  | rosetta
# Processing Record 4 of 633  | broome
# Processing Record 5 of 633  | ostrovnoy
# Processing Record 6 of 633  | lompoc
# Processing Record 7 of 633  | codrington
# Processing Record 8 of 633  | bluff
# Processing Record 9 of 633  | ushuaia
# Processing Record 10 of 633  | rikitea
# Processing Record 11 of 633  | kamaishi
# Processing Record 12 of 633  | santa marta
# Processing Record 13 of 633  | new norfolk
# Processing Record 14 of 633  | upernavik
# Processing Record 15 of 633  | rungata
# City not found. Skipping...
# Processing Record 16 of 633  | praia
# Processing Record 17 of 633  | turkistan
# City not found. Skipping...
# Processing Record 18 of 633  | mys shmidta
# City not found. Skipping...
# Processing Record 19 of 633  | bredasdorp
# Processing Record 20 of 633  | hasaki
# Processing Record 21 of 633  | manali
# Processing Record 22 of 633  | cherskiy
# Processing Record 23 of 633  | port alfred
# Processing Record 24 of 633  | abha
# Processing Record 25 of 633  | butaritari
# Processing Record 26 of 633  | bilma
# Processing Record 27 of 633  | vaini
# Processing Record 28 of 633  | hilo
# Processing Record 29 of 633  | hamilton
# Processing Record 30 of 633  | wyndham
# Processing Record 31 of 633  | ponta do sol
# Processing Record 32 of 633  | hermanus
# Processing Record 33 of 633  | biltine
# Processing Record 34 of 633  | taolanaro
# City not found. Skipping...
# Processing Record 35 of 633  | nikolskoye
# Processing Record 36 of 633  | qaanaaq
# Processing Record 37 of 633  | cape town
# Processing Record 38 of 633  | balikpapan
# Processing Record 39 of 633  | daniel flores
# Processing Record 40 of 633  | mercedes
# Processing Record 41 of 633  | lavrentiya
# Processing Record 42 of 633  | tiksi
# Processing Record 43 of 633  | riberalta
# Processing Record 44 of 633  | sai buri
# Processing Record 45 of 633  | lodi
# Processing Record 46 of 633  | atuona
# Processing Record 47 of 633  | katangli
# Processing Record 48 of 633  | bengkulu
# City not found. Skipping...
# Processing Record 49 of 633  | kasongo-lunda
# Processing Record 50 of 633  | grand gaube
# Processing Record 51 of 633  | punta arenas
# Processing Record 52 of 633  | hobart
# Processing Record 53 of 633  | dalbandin
# Processing Record 54 of 633  | bejar
# Processing Record 55 of 633  | paharpur
# Processing Record 56 of 633  | tello
# Processing Record 57 of 633  | richards bay
# Processing Record 58 of 633  | hithadhoo
# Processing Record 59 of 633  | albany
# Processing Record 60 of 633  | mataura
# Processing Record 61 of 633  | saint-philippe
# Processing Record 62 of 633  | husavik
# Processing Record 63 of 633  | kaitangata
# Processing Record 64 of 633  | victoria
# Processing Record 65 of 633  | oktyabrskoye
# Processing Record 66 of 633  | half moon bay
# Processing Record 67 of 633  | coihaique
# Processing Record 68 of 633  | ribeira grande
# Processing Record 69 of 633  | hofn
# Processing Record 70 of 633  | aklavik
# Processing Record 71 of 633  | belmonte
# Processing Record 72 of 633  | pevek
# Processing Record 73 of 633  | port elizabeth
# Processing Record 74 of 633  | almunecar
# Processing Record 75 of 633  | tsihombe
# City not found. Skipping...
# Processing Record 76 of 633  | college
# Processing Record 77 of 633  | sistranda
# Processing Record 78 of 633  | tasiilaq
# Processing Record 79 of 633  | lorengau
# Processing Record 80 of 633  | ibra
# Processing Record 81 of 633  | okakarara
# Processing Record 82 of 633  | seoul
# Processing Record 83 of 633  | sangar
# Processing Record 84 of 633  | abu dhabi
# Processing Record 85 of 633  | buraydah
# Processing Record 86 of 633  | jamestown
# Processing Record 87 of 633  | marinette
# Processing Record 88 of 633  | pisco
# Processing Record 89 of 633  | arraial do cabo
# Processing Record 90 of 633  | chuy
# Processing Record 91 of 633  | narsaq
# Processing Record 92 of 633  | ouidah
# Processing Record 93 of 633  | vaitupu
# City not found. Skipping...
# Processing Record 94 of 633  | durban
# Processing Record 95 of 633  | khatanga
# Processing Record 96 of 633  | antalaha
# Processing Record 97 of 633  | busselton
# Processing Record 98 of 633  | vardo
# Processing Record 99 of 633  | mongu
# Processing Record 100 of 633  | goderich
# Processing Record 101 of 633  | mar del plata
# Processing Record 102 of 633  | georgetown
# Processing Record 103 of 633  | verkh-usugli
# Processing Record 104 of 633  | bethel
# Processing Record 105 of 633  | omboue
# Processing Record 106 of 633  | kapaa
# Processing Record 107 of 633  | tolaga bay
# Processing Record 108 of 633  | bayevo
# Processing Record 109 of 633  | ascension
# City not found. Skipping...
# Processing Record 110 of 633  | encruzilhada
# Processing Record 111 of 633  | tarata
# Processing Record 112 of 633  | ambilobe
# Processing Record 113 of 633  | chokurdakh
# Processing Record 114 of 633  | carnarvon
# Processing Record 115 of 633  | boa vista
# Processing Record 116 of 633  | constitucion
# Processing Record 117 of 633  | warqla
# City not found. Skipping...
# Processing Record 118 of 633  | katsuura
# Processing Record 119 of 633  | quatre cocos
# Processing Record 120 of 633  | biritiba-mirim
# Processing Record 121 of 633  | weiser
# Processing Record 122 of 633  | portland
# Processing Record 123 of 633  | palaiokhora
# City not found. Skipping...
# Processing Record 124 of 633  | saint-denis
# Processing Record 125 of 633  | palabuhanratu
# City not found. Skipping...
# Processing Record 126 of 633  | faanui
# Processing Record 127 of 633  | auki
# Processing Record 128 of 633  | tuktoyaktuk
# Processing Record 129 of 633  | sentyabrskiy
# City not found. Skipping...
# Processing Record 130 of 633  | torbay
# Processing Record 131 of 633  | cockburn town
# Processing Record 132 of 633  | kodiak
# Processing Record 133 of 633  | lovozero
# Processing Record 134 of 633  | daro
# Processing Record 135 of 633  | buin
# Processing Record 136 of 633  | barrow
# Processing Record 137 of 633  | illoqqortoormiut
# City not found. Skipping...
# Processing Record 138 of 633  | mayo
# Processing Record 139 of 633  | talara
# Processing Record 140 of 633  | sagana
# Processing Record 141 of 633  | ust-nera
# Processing Record 142 of 633  | hambantota
# Processing Record 143 of 633  | wanaka
# Processing Record 144 of 633  | santona
# Processing Record 145 of 633  | klaksvik
# Processing Record 146 of 633  | nyrob
# Processing Record 147 of 633  | barcelos
# Processing Record 148 of 633  | sao jose dos campos
# Processing Record 149 of 633  | merauke
# Processing Record 150 of 633  | fuerte
# Processing Record 151 of 633  | jumla
# Processing Record 152 of 633  | bafoulabe
# Processing Record 153 of 633  | tura
# Processing Record 154 of 633  | fujin
# Processing Record 155 of 633  | norman wells
# Processing Record 156 of 633  | kisangani
# Processing Record 157 of 633  | tidore
# City not found. Skipping...
# Processing Record 158 of 633  | esperance
# Processing Record 159 of 633  | beringovskiy
# Processing Record 160 of 633  | harindanga
# Processing Record 161 of 633  | clyde river
# Processing Record 162 of 633  | poum
# Processing Record 163 of 633  | japura
# Processing Record 164 of 633  | cabo san lucas
# Processing Record 165 of 633  | belushya guba
# City not found. Skipping...
# Processing Record 166 of 633  | adrar
# Processing Record 167 of 633  | thompson
# Processing Record 168 of 633  | harper
# Processing Record 169 of 633  | belyy gorodok
# Processing Record 170 of 633  | wukari
# Processing Record 171 of 633  | pangnirtung
# Processing Record 172 of 633  | mount gambier
# Processing Record 173 of 633  | boueni
# Processing Record 174 of 633  | wattegama
# Processing Record 175 of 633  | varzea grande
# Processing Record 176 of 633  | yeniseysk
# Processing Record 177 of 633  | yellowknife
# Processing Record 178 of 633  | havoysund
# Processing Record 179 of 633  | saint george
# Processing Record 180 of 633  | souillac
# Processing Record 181 of 633  | nuuk
# Processing Record 182 of 633  | marienburg
# Processing Record 183 of 633  | ngukurr
# City not found. Skipping...
# Processing Record 184 of 633  | hovd
# Processing Record 185 of 633  | jutai
# Processing Record 186 of 633  | bag
# Processing Record 187 of 633  | samarai
# Processing Record 188 of 633  | uren
# City not found. Skipping...
# Processing Record 189 of 633  | mahebourg
# Processing Record 190 of 633  | puerto ayora
# Processing Record 191 of 633  | nyurba
# Processing Record 192 of 633  | san patricio
# Processing Record 193 of 633  | castro
# Processing Record 194 of 633  | halifax
# Processing Record 195 of 633  | cockburn harbour
# City not found. Skipping...
# Processing Record 196 of 633  | kiama
# Processing Record 197 of 633  | kavieng
# Processing Record 198 of 633  | prado
# Processing Record 199 of 633  | kieta
# Processing Record 200 of 633  | korla
# City not found. Skipping...
# Processing Record 201 of 633  | green river
# Processing Record 202 of 633  | konitsa
# Processing Record 203 of 633  | provideniya
# Processing Record 204 of 633  | fairmont
# Processing Record 205 of 633  | dikson
# Processing Record 206 of 633  | geraldton
# Processing Record 207 of 633  | burnie
# Processing Record 208 of 633  | nieuw nickerie
# Processing Record 209 of 633  | palu
# Processing Record 210 of 633  | reiskirchen
# Processing Record 211 of 633  | vinh
# Processing Record 212 of 633  | hamada
# Processing Record 213 of 633  | grand river south east
# City not found. Skipping...
# Processing Record 214 of 633  | balloch
# Processing Record 215 of 633  | nhulunbuy
# Processing Record 216 of 633  | onguday
# Processing Record 217 of 633  | pontianak
# Processing Record 218 of 633  | marakkanam
# Processing Record 219 of 633  | artyom
# Processing Record 220 of 633  | artyk
# City not found. Skipping...
# Processing Record 221 of 633  | iberia
# Processing Record 222 of 633  | dubrovytsya
# Processing Record 223 of 633  | sao paulo de olivenca
# Processing Record 224 of 633  | los llanos de aridane
# Processing Record 225 of 633  | starobaltachevo
# Processing Record 226 of 633  | coquimbo
# Processing Record 227 of 633  | porto walter
# Processing Record 228 of 633  | uniao
# City not found. Skipping...
# Processing Record 229 of 633  | shahumyan
# Processing Record 230 of 633  | arlit
# Processing Record 231 of 633  | tambovka
# Processing Record 232 of 633  | cedar city
# Processing Record 233 of 633  | bambous virieux
# Processing Record 234 of 633  | saint-joseph
# Processing Record 235 of 633  | abu samrah
# Processing Record 236 of 633  | moose factory
# Processing Record 237 of 633  | san isidro
# Processing Record 238 of 633  | marsa matruh
# Processing Record 239 of 633  | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 240 of 633  | pierre
# Processing Record 241 of 633  | mangalagiri
# Processing Record 242 of 633  | faya
# Processing Record 243 of 633  | teeli
# Processing Record 244 of 633  | tucuman
# Processing Record 245 of 633  | malabo
# Processing Record 246 of 633  | fortuna
# Processing Record 247 of 633  | uppsala
# Processing Record 248 of 633  | guane
# Processing Record 249 of 633  | boende
# Processing Record 250 of 633  | tilichiki
# Processing Record 251 of 633  | khandbari
# Processing Record 252 of 633  | atar
# Processing Record 253 of 633  | marcona
# City not found. Skipping...
# Processing Record 254 of 633  | salta
# Processing Record 255 of 633  | darnah
# Processing Record 256 of 633  | penzance
# Processing Record 257 of 633  | chimbote
# Processing Record 258 of 633  | hvide sande
# Processing Record 259 of 633  | port blair
# Processing Record 260 of 633  | mouzakion
# City not found. Skipping...
# Processing Record 261 of 633  | barentsburg
# City not found. Skipping...
# Processing Record 262 of 633  | lata
# Processing Record 263 of 633  | bayan
# Processing Record 264 of 633  | balaipungut
# Processing Record 265 of 633  | puro
# Processing Record 266 of 633  | fukue
# Processing Record 267 of 633  | bolungarvik
# City not found. Skipping...
# Processing Record 268 of 633  | saldanha
# Processing Record 269 of 633  | asfi
# City not found. Skipping...
# Processing Record 270 of 633  | inhambane
# Processing Record 271 of 633  | sao miguel do araguaia
# Processing Record 272 of 633  | ajdabiya
# Processing Record 273 of 633  | omsukchan
# Processing Record 274 of 633  | rio grande
# Processing Record 275 of 633  | severo-yeniseyskiy
# Processing Record 276 of 633  | gimli
# Processing Record 277 of 633  | baiyin
# Processing Record 278 of 633  | menongue
# Processing Record 279 of 633  | amderma
# City not found. Skipping...
# Processing Record 280 of 633  | olafsvik
# City not found. Skipping...
# Processing Record 281 of 633  | zelezna ruda
# Processing Record 282 of 633  | sisimiut
# Processing Record 283 of 633  | port hardy
# Processing Record 284 of 633  | attawapiskat
# City not found. Skipping...
# Processing Record 285 of 633  | corby
# Processing Record 286 of 633  | kupang
# Processing Record 287 of 633  | ijaki
# City not found. Skipping...
# Processing Record 288 of 633  | troitskoye
# Processing Record 289 of 633  | tutoia
# Processing Record 290 of 633  | durant
# Processing Record 291 of 633  | tromso
# Processing Record 292 of 633  | champaign
# Processing Record 293 of 633  | majene
# Processing Record 294 of 633  | yar-sale
# Processing Record 295 of 633  | toliary
# City not found. Skipping...
# Processing Record 296 of 633  | stonewall
# Processing Record 297 of 633  | saquarema
# Processing Record 298 of 633  | batemans bay
# Processing Record 299 of 633  | maragogi
# Processing Record 300 of 633  | hervey bay
# Processing Record 301 of 633  | kahului
# Processing Record 302 of 633  | lokosovo
# Processing Record 303 of 633  | port-gentil
# Processing Record 304 of 633  | sterling
# Processing Record 305 of 633  | sembakung
# Processing Record 306 of 633  | maniitsoq
# Processing Record 307 of 633  | shar
# Processing Record 308 of 633  | makung
# City not found. Skipping...
# Processing Record 309 of 633  | grand-santi
# Processing Record 310 of 633  | san pedro
# Processing Record 311 of 633  | kedrovyy
# Processing Record 312 of 633  | alofi
# Processing Record 313 of 633  | luorong
# Processing Record 314 of 633  | tautira
# Processing Record 315 of 633  | kathu
# Processing Record 316 of 633  | neuquen
# Processing Record 317 of 633  | jardim
# Processing Record 318 of 633  | oriximina
# Processing Record 319 of 633  | ayorou
# Processing Record 320 of 633  | severo-kurilsk
# Processing Record 321 of 633  | mildura
# Processing Record 322 of 633  | safwah
# City not found. Skipping...
# Processing Record 323 of 633  | petrov val
# Processing Record 324 of 633  | port augusta
# Processing Record 325 of 633  | nanortalik
# Processing Record 326 of 633  | pont-a-mousson
# Processing Record 327 of 633  | mani
# Processing Record 328 of 633  | saint-pierre
# Processing Record 329 of 633  | karratha
# Processing Record 330 of 633  | praia da vitoria
# Processing Record 331 of 633  | longyearbyen
# Processing Record 332 of 633  | barbastro
# Processing Record 333 of 633  | montepuez
# Processing Record 334 of 633  | nizhneyansk
# City not found. Skipping...
# Processing Record 335 of 633  | iqaluit
# Processing Record 336 of 633  | pangoa
# Processing Record 337 of 633  | port hedland
# Processing Record 338 of 633  | lolua
# City not found. Skipping...
# Processing Record 339 of 633  | novyy urengoy
# Processing Record 340 of 633  | sao filipe
# Processing Record 341 of 633  | monteiro
# Processing Record 342 of 633  | northam
# Processing Record 343 of 633  | matay
# Processing Record 344 of 633  | bereda
# Processing Record 345 of 633  | zhanaozen
# Processing Record 346 of 633  | campbell river
# Processing Record 347 of 633  | lewiston
# Processing Record 348 of 633  | coolum beach
# Processing Record 349 of 633  | micheweni
# Processing Record 350 of 633  | sabha
# Processing Record 351 of 633  | homer
# Processing Record 352 of 633  | cam ranh
# Processing Record 353 of 633  | kozhevnikovo
# Processing Record 354 of 633  | am timan
# Processing Record 355 of 633  | arkhangelsk
# Processing Record 356 of 633  | galesong
# Processing Record 357 of 633  | caravelas
# Processing Record 358 of 633  | saint-prosper
# Processing Record 359 of 633  | yanam
# Processing Record 360 of 633  | biak
# Processing Record 361 of 633  | hirara
# Processing Record 362 of 633  | yasothon
# Processing Record 363 of 633  | zunyi
# Processing Record 364 of 633  | brae
# Processing Record 365 of 633  | palmer
# Processing Record 366 of 633  | salalah
# Processing Record 367 of 633  | bella vista
# Processing Record 368 of 633  | barbate
# Processing Record 369 of 633  | nome
# Processing Record 370 of 633  | alpine
# Processing Record 371 of 633  | noumea
# Processing Record 372 of 633  | tirumullaivasal
# Processing Record 373 of 633  | burica
# City not found. Skipping...
# Processing Record 374 of 633  | gat
# Processing Record 375 of 633  | luwingu
# Processing Record 376 of 633  | kochki
# Processing Record 377 of 633  | sitka
# Processing Record 378 of 633  | puerto carreno
# Processing Record 379 of 633  | saskylakh
# Processing Record 380 of 633  | kahama
# Processing Record 381 of 633  | omaruru
# Processing Record 382 of 633  | hobyo
# Processing Record 383 of 633  | antofagasta
# Processing Record 384 of 633  | whitefish
# Processing Record 385 of 633  | topolobampo
# Processing Record 386 of 633  | merrill
# Processing Record 387 of 633  | kudahuvadhoo
# Processing Record 388 of 633  | kamenskoye
# City not found. Skipping...
# Processing Record 389 of 633  | qingdao
# Processing Record 390 of 633  | chinhoyi
# Processing Record 391 of 633  | eregli
# Processing Record 392 of 633  | kuala terengganu
# Processing Record 393 of 633  | gorontalo
# Processing Record 394 of 633  | pangody
# Processing Record 395 of 633  | soe
# Processing Record 396 of 633  | santa eulalia del rio
# City not found. Skipping...
# Processing Record 397 of 633  | ruwi
# Processing Record 398 of 633  | louisbourg
# City not found. Skipping...
# Processing Record 399 of 633  | soavinandriana
# Processing Record 400 of 633  | veraval
# Processing Record 401 of 633  | berlevag
# Processing Record 402 of 633  | bandundu
# Processing Record 403 of 633  | la palma
# Processing Record 404 of 633  | tondi
# Processing Record 405 of 633  | laguna
# Processing Record 406 of 633  | kilindoni
# Processing Record 407 of 633  | kaeo
# Processing Record 408 of 633  | monte patria
# Processing Record 409 of 633  | cap malheureux
# Processing Record 410 of 633  | jacmel
# Processing Record 411 of 633  | pangkalanbuun
# Processing Record 412 of 633  | galich
# Processing Record 413 of 633  | rivers
# Processing Record 414 of 633  | vinukonda
# Processing Record 415 of 633  | cidreira
# Processing Record 416 of 633  | tyup
# Processing Record 417 of 633  | rocha
# Processing Record 418 of 633  | valdivia
# Processing Record 419 of 633  | orange
# Processing Record 420 of 633  | toamasina
# Processing Record 421 of 633  | itoman
# Processing Record 422 of 633  | mareeba
# Processing Record 423 of 633  | pecos
# Processing Record 424 of 633  | turukhansk
# Processing Record 425 of 633  | changji
# Processing Record 426 of 633  | batagay-alyta
# Processing Record 427 of 633  | roberval
# Processing Record 428 of 633  | gao
# Processing Record 429 of 633  | vestmannaeyjar
# Processing Record 430 of 633  | road town
# Processing Record 431 of 633  | padang
# Processing Record 432 of 633  | mutsamudu
# City not found. Skipping...
# Processing Record 433 of 633  | itarema
# Processing Record 434 of 633  | vangaindrano
# Processing Record 435 of 633  | moundou
# Processing Record 436 of 633  | tanjong malim
# City not found. Skipping...
# Processing Record 437 of 633  | ulladulla
# Processing Record 438 of 633  | vao
# Processing Record 439 of 633  | hualmay
# Processing Record 440 of 633  | morros
# Processing Record 441 of 633  | deer lake
# Processing Record 442 of 633  | vaitape
# Processing Record 443 of 633  | althofen
# Processing Record 444 of 633  | ierapetra
# Processing Record 445 of 633  | sibolga
# Processing Record 446 of 633  | deputatskiy
# Processing Record 447 of 633  | raudeberg
# Processing Record 448 of 633  | rawah
# City not found. Skipping...
# Processing Record 449 of 633  | bubaque
# Processing Record 450 of 633  | buzmeyin
# Processing Record 451 of 633  | bury saint edmunds
# City not found. Skipping...
# Processing Record 452 of 633  | synya
# Processing Record 453 of 633  | fare
# Processing Record 454 of 633  | barahona
# Processing Record 455 of 633  | matagami
# Processing Record 456 of 633  | iranshahr
# Processing Record 457 of 633  | borogontsy
# Processing Record 458 of 633  | yerbogachen
# Processing Record 459 of 633  | zeya
# Processing Record 460 of 633  | erenhot
# Processing Record 461 of 633  | bhavnagar
# Processing Record 462 of 633  | sorong
# Processing Record 463 of 633  | praya
# Processing Record 464 of 633  | poso
# Processing Record 465 of 633  | owosso
# Processing Record 466 of 633  | tilik
# Processing Record 467 of 633  | vanavara
# Processing Record 468 of 633  | cortes
# Processing Record 469 of 633  | avera
# Processing Record 470 of 633  | okhotsk
# Processing Record 471 of 633  | taburi
# City not found. Skipping...
# Processing Record 472 of 633  | ca mau
# Processing Record 473 of 633  | xining
# Processing Record 474 of 633  | mocambique
# City not found. Skipping...
# Processing Record 475 of 633  | vila do maio
# Processing Record 476 of 633  | margate
# Processing Record 477 of 633  | barro
# Processing Record 478 of 633  | bani walid
# Processing Record 479 of 633  | jiddah
# City not found. Skipping...
# Processing Record 480 of 633  | kailua
# Processing Record 481 of 633  | vernon
# Processing Record 482 of 633  | iskateley
# Processing Record 483 of 633  | albert
# Processing Record 484 of 633  | mount isa
# Processing Record 485 of 633  | warud
# Processing Record 486 of 633  | grahamstown
# Processing Record 487 of 633  | namibe
# Processing Record 488 of 633  | touros
# Processing Record 489 of 633  | myskhako
# Processing Record 490 of 633  | tuggurt
# City not found. Skipping...
# Processing Record 491 of 633  | syracuse
# Processing Record 492 of 633  | ericeira
# Processing Record 493 of 633  | lagoa
# Processing Record 494 of 633  | irupi
# Processing Record 495 of 633  | broken hill
# Processing Record 496 of 633  | burns lake
# Processing Record 497 of 633  | hailar
# Processing Record 498 of 633  | bhalwal
# Processing Record 499 of 633  | pacific grove
# Processing Record 500 of 633  | kuche
# City not found. Skipping...
# Processing Record 501 of 633  | halalo
# City not found. Skipping...
# Processing Record 502 of 633  | vila velha
# Processing Record 503 of 633  | asamankese
# Processing Record 504 of 633  | kati
# Processing Record 505 of 633  | juifang
# City not found. Skipping...
# Processing Record 506 of 633  | kantilo
# Processing Record 507 of 633  | matara
# Processing Record 508 of 633  | bonavista
# Processing Record 509 of 633  | galdar
# Processing Record 510 of 633  | general roca
# Processing Record 511 of 633  | airai
# Processing Record 512 of 633  | sandpoint
# Processing Record 513 of 633  | havre-saint-pierre
# Processing Record 514 of 633  | paungde
# Processing Record 515 of 633  | sawakin
# Processing Record 516 of 633  | balti
# Processing Record 517 of 633  | ixtapa
# Processing Record 518 of 633  | scottsburgh
# City not found. Skipping...
# Processing Record 519 of 633  | hearst
# Processing Record 520 of 633  | shelburne
# Processing Record 521 of 633  | aykhal
# Processing Record 522 of 633  | el alto
# Processing Record 523 of 633  | aswan
# Processing Record 524 of 633  | skibbereen
# Processing Record 525 of 633  | anadyr
# Processing Record 526 of 633  | pitimbu
# Processing Record 527 of 633  | sao sebastiao
# Processing Record 528 of 633  | mvangue
# Processing Record 529 of 633  | hihifo
# City not found. Skipping...
# Processing Record 530 of 633  | minot
# Processing Record 531 of 633  | vila
# Processing Record 532 of 633  | harsud
# Processing Record 533 of 633  | saleaula
# City not found. Skipping...
# Processing Record 534 of 633  | odessa
# Processing Record 535 of 633  | petropavlovsk-kamchatskiy
# Processing Record 536 of 633  | greenville
# Processing Record 537 of 633  | mana
# Processing Record 538 of 633  | lufilufi
# Processing Record 539 of 633  | matranovak
# Processing Record 540 of 633  | ust-maya
# Processing Record 541 of 633  | flagstaff
# Processing Record 542 of 633  | ondorhaan
# City not found. Skipping...
# Processing Record 543 of 633  | dujuma
# City not found. Skipping...
# Processing Record 544 of 633  | qingquan
# Processing Record 545 of 633  | gizo
# Processing Record 546 of 633  | champerico
# Processing Record 547 of 633  | goure
# Processing Record 548 of 633  | tezu
# Processing Record 549 of 633  | golden
# Processing Record 550 of 633  | puerto quijarro
# Processing Record 551 of 633  | kutum
# Processing Record 552 of 633  | makakilo city
# Processing Record 553 of 633  | labuhan
# Processing Record 554 of 633  | portage
# Processing Record 555 of 633  | ornskoldsvik
# Processing Record 556 of 633  | guadalupe y calvo
# Processing Record 557 of 633  | tabriz
# Processing Record 558 of 633  | russell
# Processing Record 559 of 633  | pelym
# Processing Record 560 of 633  | flin flon
# Processing Record 561 of 633  | keti bandar
# Processing Record 562 of 633  | isangel
# Processing Record 563 of 633  | sovetskoye
# Processing Record 564 of 633  | formoso do araguaia
# City not found. Skipping...
# Processing Record 565 of 633  | iquitos
# Processing Record 566 of 633  | marawi
# Processing Record 567 of 633  | umm kaddadah
# Processing Record 568 of 633  | never
# Processing Record 569 of 633  | san mateo del mar
# Processing Record 570 of 633  | tamandare
# Processing Record 571 of 633  | klyuchi
# Processing Record 572 of 633  | maine-soroa
# Processing Record 573 of 633  | chapais
# Processing Record 574 of 633  | mahibadhoo
# Processing Record 575 of 633  | thanh hoa
# Processing Record 576 of 633  | san policarpo
# Processing Record 577 of 633  | saint-augustin
# Processing Record 578 of 633  | sobolevo
# Processing Record 579 of 633  | sorada
# Processing Record 580 of 633  | kharp
# Processing Record 581 of 633  | itaporanga
# Processing Record 582 of 633  | sharanga
# Processing Record 583 of 633  | missoula
# Processing Record 584 of 633  | ola
# Processing Record 585 of 633  | awjilah
# Processing Record 586 of 633  | bayir
# Processing Record 587 of 633  | beira
# Processing Record 588 of 633  | tateyama
# Processing Record 589 of 633  | ghanzi
# Processing Record 590 of 633  | samfya
# Processing Record 591 of 633  | krasnoselkup
# City not found. Skipping...
# Processing Record 592 of 633  | ulaangom
# Processing Record 593 of 633  | keetmanshoop
# Processing Record 594 of 633  | hvolsvollur
# City not found. Skipping...
# Processing Record 595 of 633  | diamantino
# Processing Record 596 of 633  | rapid valley
# Processing Record 597 of 633  | luau
# Processing Record 598 of 633  | toora-khem
# Processing Record 599 of 633  | tabuk
# Processing Record 600 of 633  | marzuq
# Processing Record 601 of 633  | sorvag
# City not found. Skipping...
# Processing Record 602 of 633  | kuching
# Processing Record 603 of 633  | segezha
# Processing Record 604 of 633  | inuvik
# Processing Record 605 of 633  | jalu
# Processing Record 606 of 633  | fairbanks
# Processing Record 607 of 633  | sola
# Processing Record 608 of 633  | wanning
# Processing Record 609 of 633  | carballo
# Processing Record 610 of 633  | chapada dos guimaraes
# Processing Record 611 of 633  | dicabisagan
# Processing Record 612 of 633  | chapleau
# Processing Record 613 of 633  | sungaipenuh
# Processing Record 614 of 633  | mount darwin
# Processing Record 615 of 633  | la asuncion
# Processing Record 616 of 633  | kruisfontein
# Processing Record 617 of 633  | ceres
# Processing Record 618 of 633  | bakchar
# Processing Record 619 of 633  | kalmunai
# Processing Record 620 of 633  | shimoda
# Processing Record 621 of 633  | nimaparha
# Processing Record 622 of 633  | leningradskiy
# Processing Record 623 of 633  | saskatoon
# Processing Record 624 of 633  | kozhva
# Processing Record 625 of 633  | dhadar
# Processing Record 626 of 633  | dingle
# Processing Record 627 of 633  | albanel
# Processing Record 628 of 633  | langsa
# Processing Record 629 of 633  | chicama
# Processing Record 630 of 633  | murwillumbah
# Processing Record 631 of 633  | san jose de pare
# City not found. Skipping...
# Processing Record 632 of 633  | kortkeros

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_dict = {"City" :name, "Cloudiness":cloudiness,
                "Country":country, "Date":date,
                "Humidity":humidity, "Lat":lat,
                "Lng":lng, "Max Temp":max_temp,
                "Wind Speed":wind_speed
    
}
cities_df = pd.DataFrame.from_dict(cities_dict)
cities_df.count()

# %%
cities_df.head()

# %%
cities_df.to_csv("output_data/cities.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_axis = cities_df["Lat"]
data = cities_df["Max Temp"]
plt.scatter(x_axis, data, marker="o", facecolors="red", alpha=0.65, edgecolors="black")
plt.title("City Latitude vs. Max Temperature (05/20/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("..output_data/Latitude vs. Temperature Plot")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis = cities_df["Lat"]
data = cities_df["Humidity"]
plt.scatter(x_axis, data, marker="o", facecolors="yellow", edgecolors="black")
plt.title("City Latitude vs. Humidity (05/20/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis = cities_df["Lat"]
data = cities_df["Cloudiness"]
plt.scatter(x_axis, data, marker="o", facecolors="orange", edgecolors="black")
plt.title("City Latitude vs. Cloudiness (05/20/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis = cities_df["Lat"]
data = cities_df["Wind Speed"]
plt.scatter(x_axis, data, marker="o", facecolors="green", alpha=0.65,  edgecolors="black")
plt.title("City Latitude vs. Wind Speed (05/20/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
